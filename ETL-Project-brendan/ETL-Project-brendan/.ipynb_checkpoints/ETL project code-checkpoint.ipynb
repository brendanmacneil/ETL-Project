# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
sat17 = "sat17.csv"
sat17_df = pd.read_csv(sat17)
sat17_df.head()
# Out:
#              cds  Ccode  CDcode   Scode rtype  \
# 0              0      0       0       0     X
# 1  1000000000000      1  100000       0     C
# 2  1100170000000      1  110017       0     D
# 3  1100170112607      1  110017  112607     S
# 4  1611190000000      1  161119       0     D
#
#                                     sname                               dname  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN  Alameda County Office of Education
# 3  Envision Academy for Arts & Technology  Alameda County Office of Education
# 4                                     NaN                     Alameda Unified
#
#      cname  enroll12  NumTstTakr NumCurrElaBenchmark NumPreElaBenchmark  \
# 0      NaN    484169      221433              144893              15103
# 1  Alameda     16638        9029                5407               1376
# 2  Alameda       253          83                  28                  0
# 3  Alameda        81          83                  28                  0
# 4  Alameda       910         495                 373                 51
#
#   TotNumElaBenchmark PctElaBenchmark NumCurrMathBenchmark NumPreMathBenchmark  \
# 0             159996           72.25                98504               13887
# 1               6783           75.12                 4033                1337
# 2                 28           33.73                    9                   0
# 3                 28           33.73                    9                   0
# 4                424           85.66                  298                  47
#
#   TotNumMathBenchmark PctMathBenchmark TotNumBothBenchmark PctBothBenchmark
# 0              112391            50.76              107173            48.40
# 1                5370            59.48                5147            57.01
# 2                   9            10.84                   9            10.84
# 3                   9            10.84                   9            10.84
# 4                 345            69.70                 330            66.67

# %%
county_file = "Income by county.csv"
county_file_df = pd.read_csv(county_file)
county_file_df.head()
# Out:
#                       Geography  Households; Estimate; Total  \
# 0    Alameda County, California                       569070
# 1     Alpine County, California                          304
# 2     Amador County, California                        14185
# 3      Butte County, California                        86167
# 4  Calaveras County, California                        17812
#
#    Households; Margin of Error; Total  Families; Estimate; Total  \
# 0                                1516                     379405
# 1                                  57                        206
# 2                                 362                       9472
# 3                                 856                      51488
# 4                                 489                      11896
#
#    Families; Margin of Error; Total  Married-couple families; Estimate; Total  \
# 0                              2280                                    282759
# 1                                49                                       171
# 2                               392                                      7766
# 3                              1019                                     37376
# 4                               552                                      9292
#
#    Married-couple families; Margin of Error; Total  \
# 0                                             2460
# 1                                               49
# 2                                              415
# 3                                              981
# 4                                              555
#
#    Nonfamily households; Estimate; Total  \
# 0                                 189665
# 1                                     98
# 2                                   4713
# 3                                  34679
# 4                                   5916
#
#    Nonfamily households; Margin of Error; Total  \
# 0                                          2117
# 1                                            30
# 2                                           421
# 3                                          1093
# 4                                           483
#
#    Households; Estimate; Less than $10,000  \
# 0                                      4.7
# 1                                      3.3
# 2                                      4.3
# 3                                      8.0
# 4                                      4.9
#
#                            ...                            \
# 0                          ...
# 1                          ...
# 2                          ...
# 3                          ...
# 4                          ...
#
#    Married-couple families; Margin of Error; Median income (dollars)  \
# 0                                               1061
# 1                                              32282
# 2                                               5357
# 3                                               1883
# 4                                               5385
#
#    Nonfamily households; Estimate; Median income (dollars)  \
# 0                                              52450
# 1                                              28611
# 2                                              27372
# 3                                              26281
# 4                                              30335
#
#    Nonfamily households; Margin of Error; Median income (dollars)  \
# 0                                                694
# 1                                              12147
# 2                                               2620
# 3                                               1152
# 4                                               4259
#
#    Households; Estimate; Mean income (dollars)  \
# 0                                       114330
# 1                                        90994
# 2                                        75677
# 3                                        66251
# 4                                        77144
#
#    Households; Margin of Error; Mean income (dollars)  \
# 0                                                945
# 1                                              21877
# 2                                               4469
# 3                                               1844
# 4                                               3421
#
#    Families; Estimate; Mean income (dollars)  \
# 0                                     131775
# 1                                     110592
# 2                                      91557
# 3                                      81547
# 4                                      92980
#
#    Families; Margin of Error; Mean income (dollars)  \
# 0                                              1222
# 1                                             30044
# 2                                              5778
# 3                                              2988
# 4                                              4705
#
#    Married-couple families; Estimate; Mean income (dollars)  \
# 0                                             151724
# 1                                                  N
# 2                                                  N
# 3                                              95230
# 4                                                  N
#
#    Married-couple families; Margin of Error; Mean income (dollars)  \
# 0                                               1290
# 1                                                  N
# 2                                                  N
# 3                                               3576
# 4                                                  N
#
#    Nonfamily households; Estimate; Mean income (dollars)
# 0                                              73298
# 1                                              47028
# 2                                              39939
# 3                                              41019
# 4                                              43678
#
# [5 rows x 104 columns]

# %%
 # Create a filtered dataframe from specific columns
sat17_cols = ["cname", "TotNumBothBenchmark", "PctBothBenchmark"]
sat17_transformed= sat17_df[sat17_cols].copy()

# %%
# Rename the column headers
sat17_transformed = sat17_transformed.rename(columns={"cname": "County",
                                                          "TotNumBothBenchmark":"Total Number Benchmark" ,
                                                          "PctBothBenchmark": "Percentage Benchmark"})

# %%
# Clean the data by dropping duplicates and setting the index
#sat17_transformed.drop_duplicates("id", inplace=True)
#sat17_transformed.set_index("id", inplace=True)
#This was not needed
sat17_transformed.head()
# Out:
#     County Total Number Benchmark Percentage Benchmark
# 0      NaN                 107173                48.40
# 1  Alameda                   5147                57.01
# 2  Alameda                      9                10.84
# 3  Alameda                      9                10.84
# 4  Alameda                    330                66.67

# %%
# Create a filtered dataframe from specific columns
county_cols = ["Geography", "Households; Estimate; Total", "Nonfamily households; Estimate; Mean income (dollars)"]
county_transformed = county_file_df[county_cols].copy()

# %%
# Rename the column headers
county_transformed = county_transformed.rename(columns={"Geography": "County",
                                                         "Households; Estimate; Total": "Households; Estimate; Total",
                                                         "Nonfamily households; Estimate; Mean income (dollars)": "Nonfamily households; Estimate; Mean income (dollars)"})

# Set index
#county_transformed.set_index("id", inplace=True)

county_transformed.head()
# Out:
#                          County  Households; Estimate; Total  \
# 0    Alameda County, California                       569070
# 1     Alpine County, California                          304
# 2     Amador County, California                        14185
# 3      Butte County, California                        86167
# 4  Calaveras County, California                        17812
#
#    Nonfamily households; Estimate; Mean income (dollars)
# 0                                              73298
# 1                                              47028
# 2                                              39939
# 3                                              41019
# 4                                              43678

# %%
#Creation of a new database
connection_string = "root:password@localhost/"
engine = create_engine(f'mysql://{connection_string}')

connection = engine.connect()

# %%
connection.execute('create schema new_db')

# %%
db_connection = "root:password@localhost/new_db"
db_engine = create_engine(f'mysql://{db_connection}')

#confirm tables
db_engine.table_names()
# Out:
# []

# %%
[]
# Out:
# []

# %%
sat17_transformed.to_sql(name= 'SAT17', con = db_engine, if_exists= 'append', index=True)
# Out:
# C:\Users\bkm32\Anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'SAT17' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
county_transformed.to_sql(name='CountyIncome', con=db_engine, if_exists='append', index=True)
# Out:
# C:\Users\bkm32\Anaconda3\lib\site-packages\pandas\io\sql.py:1144: UserWarning: The provided table name 'CountyIncome' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   warnings.warn(msg, UserWarning)

# %%
db_engine.table_names()
# Out:
# ['county', 'countyincome', 'sat17']
